# %%
"""
This code aims to extract scenes from a .mp4 video 
ref: https://pyscenedetect.readthedocs.io/en/latest/examples/usage-example/#finding-optimal-thresholdsensitivity-value 
"""

# %%
# !pip install scenedetect[opencv]
# Out:
# Collecting scenedetect[opencv]
#   Downloading scenedetect-0.5.6.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 5.3 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from scenedetect[opencv]) (4.62.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scenedetect[opencv]) (1.19.5)
# Requirement already satisfied: Click in /usr/local/lib/python3.7/dist-packages (from scenedetect[opencv]) (7.1.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from scenedetect[opencv]) (4.1.2.30)
# Installing collected packages: scenedetect
# Successfully installed scenedetect-0.5.6.1

# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from tqdm import tqdm 
import time
import json
# Standard PySceneDetect imports:
from scenedetect import VideoManager
from scenedetect import SceneManager
# For content-aware scene detection:
from scenedetect.detectors import ContentDetector

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root = "/content/drive/My Drive/Let-Hunt-Youtube/"
config_file_path = os.path.join(root, 'config.json')

config = json.load(open(config_file_path))

video_folder = config['folder']['video']
database_folder = config['folder']['database']

video_folder_path = os.path.join(root, video_folder)
video_save_folder_path = os.path.join(root, video_folder, 'Save')

# %%
def find_scenes(video_path, threshold=30.0):
    # Create our video & scene managers, then add the detector.
    video_manager = VideoManager([video_path])
    scene_manager = SceneManager()
    scene_manager.add_detector(
        ContentDetector(threshold=threshold))

    # Improve processing speed by downscaling before processing.
    video_manager.set_downscale_factor()

    # Start the video manager and perform the scene detection.
    video_manager.start()
    scene_manager.detect_scenes(frame_source=video_manager)

    # Each returned scene is a tuple of the (start, end) timecode.
    return scene_manager.get_scene_list()

# %%
video_00005_file_path = os.path.join(video_folder_path, 'video00005.mp4')
# scene_list = find_scenes(video_00005_file_path)

# %%
len(scene_list)
# Out:
# 68

# %%
# !scenedetect -i "$video_00005_file_path" -o "$video_save_folder_path" detect-content -t 27 list-scenes save-images split-video
# Out:
# [PySceneDetect] PySceneDetect v0.5.6.1
# [PySceneDetect] Output directory set:
#   /content/drive/My Drive/Let-Hunt-Youtube/Videos/Save
# [PySceneDetect] Loaded 1 video, framerate: 30.000 FPS, resolution: 1280 x 720
# [PySceneDetect] Downscale factor set to 5, effective resolution: 256 x 144
# [PySceneDetect] Scene list CSV file name format:
#   $VIDEO_NAME-Scenes.csv
# [PySceneDetect] Image output format set: JPEG [Quality: 95]
# [PySceneDetect] FFmpeg codec args set: -c:v libx264 -preset veryfast -crf 22 -c:a aac
# [PySceneDetect] Video output file name format: $VIDEO_NAME-Scene-$SCENE_NUMBER
# [PySceneDetect] Detecting scenes...
# 100% 12053/12053 [01:08<00:00, 175.82frames/s]
# [PySceneDetect] Processed 12053 frames in 68.6 seconds (average 175.80 FPS).
# [PySceneDetect] Detected 109 scenes, average shot length 3.7 seconds.
# [PySceneDetect] Writing scene list to CSV file:
#   /content/drive/My Drive/Let-Hunt-Youtube/Videos/Save/video00005-Scenes.csv
using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5612d727c800] profile High, level 3.1
# [libx264 @ 0x5612d727c800] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=22.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/My Drive/Let-Hunt-Youtube/Videos/Save/video00005-Scene-001.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2021-10-13T14:23:11.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/13/2021.
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-13T14:23:11.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/13/2021.
#       encoder         : Lavc57.107.100 aac
# frame=  304 fps= 66 q=-1.0 Lsize=    1373kB time=00:00:10.14 bitrate=1108.5kbits/s speed= 2.2x
# video:1205kB audio:156kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.881768%
# [libx264 @ 0x5612d727c800] frame I:2     Avg QP:15.86  size: 23594
# [libx264 @ 0x5612d727c800] frame P:93    Avg QP:17.93  size:  7728
# [libx264 @ 0x5612d727c800] frame B:209   Avg QP:22.54  size:  2234
# [libx264 @ 0x5612d727c800] consecutive B-frames:  5.9%  5.9%  3.9% 84.2%
# [libx264 @ 0x5612d727c800] mb I  I16..4: 47.0% 37.4% 15.6%
# [libx264 @ 0x5612d727c800] mb P  I16..4: 10.7%  4.4%  0.4%  P16..4: 11.4%  6.7%  4.2%  0.0%  0.0%    skip:62.2%
# [libx264 @ 0x5612d727c800] mb B  I16..4:  1.0%  0.3%  0.0%  B16..8: 10.4%  3.5%  0.5%  direct: 2.7%  skip:81.4%  L0:45.1% L1:44.1% BI:10.8%
# [libx264 @ 0x5612d727c800] 8x8 transform intra:28.8% inter:21.4%
# [libx264 @ 0x5612d727c800] coded y,uvDC,uvAC intra: 16.1% 28.1% 5.3% inter: 3.1% 5.8% 0.2%
# [libx264 @ 0x5612d727c800] i16 v,h,dc,p: 67% 23%  9%  2%
# [libx264 @ 0x5612d727c800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 22% 33%  1%  2%  2%  2%  1%  1%
# [libx264 @ 0x5612d727c800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 19% 16%  4%  6%  7%  6%  5%  3%
# [libx264 @ 0x5612d727c800] i8c dc,h,v,p: 57% 17% 21%  5%
# [libx264 @ 0x5612d727c800] Weighted P-Frames: Y:1.1% UV:0.0%
# [libx264 @ 0x5612d727c800] kb/s:973.30
# [aac @ 0x5612d727d700] Qavg: 19468.152
# [PySceneDetect] Output from ffmpeg for Scene 1 shown above, splitting remaining scenes...
# 100% 12053/12053 [05:23<00:00, 38.46frame/s]
# [PySceneDetect] Average processing speed 37.30 frames/sec.
# 100% 12053/12053 [05:23<00:00, 37.30frame/s]
# [PySceneDetect] Video splitting completed, individual scenes written to disk.

# %%
pip3 install https://github.com/drivendataorg/zamba/releases/latest/download/zamba.tar.gz

# %%
import zamba

# %%
video_00005_scene001_file_path = os.path.join(video_folder_path, 'Save', "Scene-001")
# !zamba predict --data-dir "$video_00005_scene001_file_path" --model european
# Out:
# 2021-12-16 10:13:44.030 | INFO     | zamba.models.config:get_filepaths:690 - Getting files in /content/drive/My Drive/Let-Hunt-Youtube/Videos/Save/Scene-001.
# 2021-12-16 10:13:44.032 | INFO     | zamba.models.config:get_filepaths:711 - Found 1 videos in /content/drive/My Drive/Let-Hunt-Youtube/Videos/Save/Scene-001.
# 2021-12-16 10:13:44.037 | INFO     | zamba.models.config:check_files_exist_and_load:105 - Checking all 1 filepaths exist. Can take up to a minute for every couple thousand files.
# 2021-12-16 10:13:44.039 | INFO     | zamba.models.config:check_files_exist_and_load:130 - Checking that all videos can be loaded. If you're very confident all your videos can be loaded, you can skip this with `skip_load_validation`, but it's not recommended.
# 100% 1/1 [00:00<00:00, 11.42it/s]
# The following configuration will be used for inference:
#
#     Config file: None
#     Data directory: /content/drive/My Drive/Let-Hunt-Youtube/Videos/Save/Scene-001
#     Filepath csv: None
#     Model: european
#     Checkpoint: None
#     Batch size: 2
#     Number of workers: 3
#     GPUs: 0
#     Dry run: False
#     Save directory: /content
#     Proba threshold: None
#     Output class names: False
#     Weight download region: us
#
#
# Is this correct? [Y/n]: y
# 2021-12-16 10:13:49.092 | INFO     | zamba.models.model_manager:instantiate_model:83 - Downloading weights for model.
# 2021-12-16 10:13:52.468 | INFO     | zamba.models.model_manager:instantiate_model:94 - Instantiating model: TimeDistributedEfficientNet
# 2021-12-16 10:13:52.468 | INFO     | zamba.models.model_manager:instantiate_model:98 - Loading from checkpoint.
# 2021-12-16 10:13:54.513 | INFO     | zamba.models.model_manager:predict_model:364 - No cache dir is specified. Videos will not be cached.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# 2021-12-16 10:13:54.517 | INFO     | zamba.models.model_manager:predict_model:383 - Writing out full configuration to /content/predict_configuration.yaml.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 2021-12-16 10:13:54.523 | INFO     | zamba.models.model_manager:predict_model:388 - Starting prediction...
# Predicting: 0it [00:00, ?it/s]/usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/epoch/prediction_epoch_loop.py:172: UserWarning: Lightning couldn't infer the indices fetched for your dataloader.
#   warning_cache.warn("Lightning couldn't infer the indices fetched for your dataloader.")
# 2021-12-16 10:14:02.413 | WARNING  | zamba.pytorch.dataloaders:__getitem__:119 - Video /content/drive/My Drive/Let-Hunt-Youtube/Videos/Save/Scene-001/video00005-Scene-001.mp4 could not be loaded. Using an array of all zeros instead.
# Predicting:   0% 0/1 [00:17<?, ?it/s]
# 2021-12-16 10:14:12.144 | INFO     | zamba.models.model_manager:predict_model:408 - Saving out predictions to /content/zamba_predictions.csv.

# %%
# !cat zamba_predictions.csv
# Out:
# cat: unrecognized option '--model'
# Try 'cat --help' for more information.
